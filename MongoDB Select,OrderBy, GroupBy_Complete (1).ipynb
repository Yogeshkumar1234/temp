# %%
import pymongo
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')



db = client['books']



books = db.books



db.books.insert_many([{"book": "The Ranch", "author": "Danielle Steel"},
                                {"book": "The Firm", "author": "John Grisham"},
                                {"book": "The runaway jury", "author": "John Grisham"},
                                {"book": "Time to kill", "author": "John Grisham"},
                                {"book": "The testament", "author": "John Grisham"},
                                {"book": "Tell me your Dreams", "author": "Sidney Sheldon"}
                              ])



for book in books.find():
  print(book)



books.find_one({'author':"Danielle Steel"})



for book in books.find({'author':"Sidney Sheldon"}):
    print(book)



for book in books.find({'author':"John Grisham"}):
    print(book['book'])



for book in books.find().sort([("author", pymongo.ASCENDING)]):
  print(book)



pipeline = [
     {"$group": {"_id": "$author", "count": {"$sum": 1}}}]

grp_books = db.books.aggregate(pipeline)



for book in grp_books:
  print(book)
# Out:
# {'_id': ObjectId('60d94b49fb538dd9168a7ac2'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d94c4d8a2fddc8a9156d25'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d94f0febdbb20aa9269b78'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d95057e6ce761a359619c4'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60da707f33264ae6243b47e8'), 'book': 'The Ranch', 'author': 'Danielle Steel'}
# {'_id': ObjectId('60da707f33264ae6243b47e9'), 'book': 'The Firm', 'author': 'John Grisham'}
# {'_id': ObjectId('60da707f33264ae6243b47ea'), 'book': 'The runaway jury', 'author': 'John Grisham'}
# {'_id': ObjectId('60da707f33264ae6243b47eb'), 'book': 'Time to kill', 'author': 'John Grisham'}
# {'_id': ObjectId('60da707f33264ae6243b47ec'), 'book': 'The testament', 'author': 'John Grisham'}
# {'_id': ObjectId('60da707f33264ae6243b47ed'), 'book': 'Tell me your Dreams', 'author': 'Sidney Sheldon'}
# {'_id': ObjectId('60d94b49fb538dd9168a7ac2'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d94c4d8a2fddc8a9156d25'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d94f0febdbb20aa9269b78'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d95057e6ce761a359619c4'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60da707f33264ae6243b47ed'), 'book': 'Tell me your Dreams', 'author': 'Sidney Sheldon'}
# The Firm
# The runaway jury
# Time to kill
# The testament
# {'_id': ObjectId('60da707f33264ae6243b47e8'), 'book': 'The Ranch', 'author': 'Danielle Steel'}
# {'_id': ObjectId('60da707f33264ae6243b47e9'), 'book': 'The Firm', 'author': 'John Grisham'}
# {'_id': ObjectId('60da707f33264ae6243b47ea'), 'book': 'The runaway jury', 'author': 'John Grisham'}
# {'_id': ObjectId('60da707f33264ae6243b47eb'), 'book': 'Time to kill', 'author': 'John Grisham'}
# {'_id': ObjectId('60da707f33264ae6243b47ec'), 'book': 'The testament', 'author': 'John Grisham'}
# {'_id': ObjectId('60d94b49fb538dd9168a7ac2'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d94c4d8a2fddc8a9156d25'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d94f0febdbb20aa9269b78'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60d95057e6ce761a359619c4'), 'author': 'Sidney Sheldon', 'about': 'Tell Me Your Dreams', 'tags': ['MPD', 'Murder', 'Mystery']}
# {'_id': ObjectId('60da707f33264ae6243b47ed'), 'book': 'Tell me your Dreams', 'author': 'Sidney Sheldon'}
# {'_id': 'Sidney Sheldon', 'count': 5}
# {'_id': 'Danielle Steel', 'count': 1}
# {'_id': 'John Grisham', 'count': 4}
